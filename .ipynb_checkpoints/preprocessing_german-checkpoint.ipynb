# %%
import re
import numpy as np
import emoji as emoji
import string
import pandas as pd
import csv
from sklearn.feature_extraction import text
 
data = pd.read_csv("translated_german.csv")
datas= data['Tweet'].tolist()
new = list()

file = open("clean_german.csv", "w")
writer = csv.writer(file)
 
emoticons = [':-)', ':)', '(:', '(-:', ':))', '((:', ':-D', ':D', 'X-D', 'XD', 'xD', 'xD', '<3', '</3', ':\*',
             ';-)',
             ';)', ';-D', ';D', '(;', '(-;', ':-(', ':(', '(:', '(-:', ':,(', ':\'(', ':"(', ':((', ':D', '=D',
             '=)',
             '(=', '=(', ')=', '=-O', 'O-=', ':o', 'o:', 'O:', 'O:', ':-o', 'o-:', ':P', ':p', ':S', ':s', ':@',
             ':>',
             ':<', '^_^', '^.^', '>.>', 'T_T', 'T-T', '-.-', '*.*', '~.~', ':*', ':-*', 'xP', 'XP', 'XP', 'Xp',
             ':-|',
             ':->', ':-<', '$_$', '8-)', ':-P', ':-p', '=P', '=p', ':*)', '*-*', 'B-)', 'O.o', 'X-(', ')-X']
for value in datas:
    text = value.replace(".", " ").lower()
    text = re.sub(r"[^a-zA-Z?.!,¿]+", " ", text)
    users = re.findall("[@]\w+", text)
    for user in users:
        text = text.replace(user, "")
    urls = re.findall(r'(https?://[^\s]+)', text)
    if len(urls) != 0:
        for url in urls:
            text = text.replace(url, "")
    for emo in text:
        if emo in emoji.UNICODE_EMOJI:
            text = text.replace(emo, "")
    for emo in emoticons:
        text = text.replace(emo, "")
    numbers = re.findall('[0-9]+', text)
    for number in numbers:
        text = text.replace(number, "")
    text = text.replace('#', "")
    text = re.sub(r"([?.!,¿])", r" ", text)
    text = "".join(l for l in text if l not in string.punctuation)
    text = re.sub(r'[" "]+', " ", text)
    writer.writerow([text])
# Out:
#  rosenmontag is cancelled rapefugees so go to the swimming pool again as usual
# please do not make t rkei a eu member human rights press freedom islamization
# why do rapefugees get more than our hartz enpf ngers it s enough
# declare war on the cursed rapefugees ren what s wrong
# i spent the weekend in the ruhrpott berall pregnant muslim women with a rat s tail on children islamization
#  asylanteninvasion when violence breaks out on our streets those responsible for this are in the government merkel
#  million people live in europe about million fl chtlinge cause headaches racists talk about islamization
# well the spd wants to miss out on our tax money for fl r fl chtlinge refugees refugeesnotwelcome refugeesgohome mark
# but for the k lner police increased ads have only one reason women are more willing to report than in rapefugees
# open free wifi in the sophienhof kiel with a reason for the pref lle of yesterday afternoon back to kabul with the rapefugees
#  unterdenlinden petry calls for better regulation of laws for asylants and migrants true why is it not done
# rules and laws of the locals are a violation of the human nature hunger strike rapefugees
